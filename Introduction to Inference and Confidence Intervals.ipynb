# %%
import pandas as pd
df =pd.read_csv('ames.csv')
df.head()
# Out:
#    Order        PID  MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot.Shape Land.Contour    ...     Pool.Area Pool.QC  Fence  \
# 0   NaN       IR1          Lvl    ...             0     NaN    NaN
# 1   NaN       Reg          Lvl    ...             0     NaN  MnPrv
# 2   NaN       IR1          Lvl    ...             0     NaN    NaN
# 3   NaN       Reg          Lvl    ...             0     NaN    NaN
# 4   NaN       IR1          Lvl    ...             0     NaN  MnPrv
#
#   Misc.Feature Misc.Val Mo.Sold Yr.Sold Sale.Type  Sale.Condition  SalePrice
# ...

# %%
area = df['Gr.Liv.Area']
price = df['SalePrice']
#df.columns
area.describe()
# Out:
# count    2930.000000
# mean     1499.690444
# std       505.508887
# min       334.000000
# 25%      1126.000000
# 50%      1442.000000
# 75%      1742.750000
# max      5642.000000
# Name: Gr.Liv.Area, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(area)
plt.show()

# %%
sampl1 = area.sample(50)

# %%
plt.hist(sampl1)
plt.show()

# %%
sampl1.mean()
# Out:
# 1515.84

# %%
sampl2 = area.sample(50)
sampl2.mean()
#plt.hist(sampl2)
#plt.show()
# Out:
# 1507.08

# %%
sampl3 = area.sample(100)
sampl3.mean()
# Out:
# 1447.97

# %%
sampl4 = area.sample(1000)
sampl4.mean()
plt.hist(sampl4)
plt.show()

# %%
sample_means = [area.sample(50).mean() for i in range(0,5000)]
sample_means
# Out:
# [1473.56,
#  1524.96,
#  1460.08,
#  1424.18,
#  1508.88,
#  1513.0,
#  1444.94,
#  1419.12,
#  1487.6,
#  1450.66,
#  1492.78,
#  1552.44,
#  1497.54,
#  1475.02,
#  1448.34,
#  1465.12,
#  1555.84,
#  1522.08,
#  1486.24,
#  1413.58,
#  1634.48,
#  1568.82,
#  1461.86,
#  1464.94,
#  1381.62,
#  1545.74,
#  1521.4,
#  1625.26,
#  1530.4,
#  1602.74,
#  1484.92,
#  1353.52,
#  1514.7,
#  1559.88,
#  1472.54,
#  1520.32,
#  1537.26,
#  1486.72,
#  1464.38,
#  1433.46,
#  1522.96,
#  1457.48,
#  1618.98,
#  1364.2,
#  1450.0,
#  1373.5,
#  1453.0,
#  1501.3,
#  1537.08,
#  1521.56,
#  1535.66,
#  1448.52,
#  1487.44,
#  1521.26,
#  1438.12,
#  1519.96,
#  1441.26,
#  1507.04,
#  1420.34,
#  1501.12,
#  1444.36,
#  1456.22,
#  1593.9,
#  1363.14,
#  1657.38,
#  1460.52,
#  1423.32,
#  1432.54,
#  1530.24,
#  1567.44,
#  1528.72,
#  1497.9,
#  1567.96,
#  1523.56,
#  1440.7,
#  1403.58,
#  1504.66,
#  1409.92,
#  1485.12,
#  1499.54,
#  1423.08,
#  1537.8,
#  1411.56,
#  1394.3,
# ...

# %%
plt.hist(sample_means)
plt.show()

# %%
sample_means = [area.sample(10).mean() for i in range(0,5000)]
plt.hist(sample_means)
plt.show()

# %%
sample_means = [area.sample(100).mean() for i in range(0,5000)]
plt.hist(sample_means)
plt.show()
#notice the decreasing spread

# %%
#Confidence intervals
sampl1 = area.sample(100)
sampl1.std()
# Out:
# 477.35242841017475

# %%
se = sampl1.std()/100
se
# Out:
# 4.773524284101748

# %%
lower = sampl1.mean()-(1.96*se)
upper = sampl1.mean()+(1.96*se)
#confidence interval (lower,upper)
(lower,upper)
# Out:
# (1493.4938924031605, 1512.2061075968393)
