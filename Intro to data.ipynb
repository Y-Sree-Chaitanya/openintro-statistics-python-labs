# %%
import pandas as pd #import pandas
df = pd.read_csv('cdc.csv',header=0) #read data

#view first 5 rows
df.head(10)
# Out:
#      genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0       good        0         1         0      70     175       175   77
# 1       good        0         1         1      64     125       115   33
# 2       good        1         1         1      60     105       105   49
# 3       good        1         1         0      66     132       124   42
# 4  very good        0         1         0      61     150       130   55
# 5  very good        1         1         0      64     114       114   55
# 6  very good        1         1         0      71     194       185   31
# 7  very good        0         1         0      67     170       160   45
# 8       good        0         1         1      65     150       130   27
# 9       good        1         1         0      70     180       170   44
#
#   gender
# 0      m
# 1      f
# 2      f
# 3      f
# 4      f
# 5      f
# 6      m
# 7      m
# 8      f
# 9      m

# %%
#view last 5 rows
df.tail()
# Out:
#          genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 19995       good        1         1         0      66     215       140   23
# 19996  excellent        0         1         0      73     200       185   35
# 19997       poor        0         1         0      65     216       150   57
# 19998       good        1         1         0      67     165       165   81
# 19999       good        1         1         1      69     170       165   83
#
#       gender
# 19995      f
# 19996      m
# 19997      f
# 19998      f
# 19999      m

# %%
#view descriptive stats
df.describe()
# Out:
#             exerany      hlthplan      smoke100        height       weight  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.00000
# mean       0.745700      0.873800      0.472050     67.182900    169.68295
# std        0.435478      0.332083      0.499231      4.125954     40.08097
# min        0.000000      0.000000      0.000000     48.000000     68.00000
# 25%        0.000000      1.000000      0.000000     64.000000    140.00000
# 50%        1.000000      1.000000      0.000000     67.000000    165.00000
# 75%        1.000000      1.000000      1.000000     70.000000    190.00000
# max        1.000000      1.000000      1.000000     93.000000    500.00000
#
#            wtdesire           age
# count  20000.000000  20000.000000
# mean     155.093850     45.068250
# std       32.013306     17.192689
# min       68.000000     18.000000
# 25%      130.000000     31.000000
# 50%      150.000000     43.000000
# 75%      175.000000     57.000000
# ...

# %%
#pandas has functions for computing descriptive stats one by one
df['weight'].mean()
# Out:
# 169.68295

# %%
df['weight'].var()
# Out:
# 17.02349876493546

# %%
df['weight'].median()
# Out:
# 165.0

# %%
df.corr()
# Out:
#            exerany  hlthplan  smoke100    height    weight  wtdesire       age
# exerany   1.000000  0.072315 -0.032695  0.112464 -0.027526  0.039595 -0.093479
# hlthplan  0.072315  1.000000 -0.032738  0.024255  0.013888  0.010648  0.194174
# smoke100 -0.032695 -0.032738  1.000000  0.081037  0.054767  0.064150  0.108565
# height    0.112464  0.024255  0.081037  1.000000  0.555322  0.758119 -0.125182
# weight   -0.027526  0.013888  0.054767  0.555322  1.000000  0.800052  0.001609
# wtdesire  0.039595  0.010648  0.064150  0.758119  0.800052  1.000000 -0.025018
# age      -0.093479  0.194174  0.108565 -0.125182  0.001609 -0.025018  1.000000

# %%
df.cov()
# Out:
#            exerany  hlthplan  smoke100      height       weight     wtdesire  \
# exerany   0.189641  0.010458 -0.007108    0.202072    -0.480450     0.551994
# hlthplan  0.010458  0.110279 -0.005428    0.033234     0.184848     0.113200
# smoke100 -0.007108 -0.005428  0.249231    0.166920     1.095868     1.025249
# height    0.202072  0.033234  0.166920   17.023499    91.834880   100.136542
# weight   -0.480450  0.184848  1.095868   91.834880  1606.484154  1026.566383
# wtdesire  0.551994  0.113200  1.025249  100.136542  1026.566383  1024.851785
# age      -0.699879  1.108619  0.931829   -8.879927     1.108694   -13.769994
#
#                  age
# exerany    -0.699879
# hlthplan    1.108619
# smoke100    0.931829
# height     -8.879927
# weight      1.108694
# wtdesire  -13.769994
# age       295.588571

# %%
#functions useful for analyzing categorical data
df['age'].value_counts()
# Out:
# 40    524
# 35    472
# 37    465
# 45    462
# 30    456
# 43    450
# 42    448
# 36    435
# 39    432
# 38    430
# 32    417
# 29    415
# 33    414
# 50    405
# 28    400
# 34    394
# 27    393
# 47    393
# 44    385
# 41    382
# 23    381
# 52    369
# 48    369
# 24    367
# 25    365
# 46    363
# 22    358
# 31    353
# 21    350
# 26    342
#      ...
# 72    192
# 61    191
# 69    191
# 73    187
# 66    186
# 71    182
# 75    180
# 76    152
# 78    130
# 80    128
# 77    124
# 79    108
# 83     80
# 82     79
# 81     70
# 84     67
# 85     57
# 87     31
# 88     24
# 86     22
# 89     15
# 91     10
# 90      9
# 93      7
# 92      6
# 94      3
# 99      2
# 95      2
# 97      1
# 96      1
# Name: age, Length: 81, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='age',data=df)
plt.show()

# %%
#subsetting
df[df['gender']=='m'].head() #another way of calling df.query
# Out:
#       genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0        good        0         1         0      70     175       175   77
# 6   very good        1         1         0      71     194       185   31
# 7   very good        0         1         0      67     170       160   45
# 9        good        1         1         0      70     180       170   44
# 10  excellent        1         1         1      69     186       175   46
#
#    gender
# 0       m
# 6       m
# 7       m
# 9       m
# 10      m
