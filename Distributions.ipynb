# %%
import pandas as pd
df = pd.read_csv('bdims.csv')
df.head()
# Out:
#    bia.di  bii.di  bit.di  che.de  che.di  elb.di  wri.di  kne.di  ank.di  \
# 0    42.9    26.0    31.5    17.7    28.0    13.1    10.4    18.8    14.1
# 1    43.7    28.5    33.5    16.9    30.8    14.0    11.8    20.6    15.1
# 2    40.1    28.2    33.3    20.9    31.7    13.9    10.9    19.7    14.1
# 3    44.3    29.9    34.0    18.4    28.2    13.9    11.2    20.9    15.0
# 4    42.5    29.9    34.0    21.5    29.4    15.2    11.6    20.7    14.9
#
#    sho.gi ...   bic.gi  for.gi  kne.gi  cal.gi  ank.gi  wri.gi  age   wgt  \
# 0   106.2 ...     32.5    26.0    34.5    36.5    23.5    16.5   21  65.6
# 1   110.5 ...     34.4    28.0    36.5    37.5    24.5    17.0   23  71.8
# 2   115.1 ...     33.4    28.8    37.0    37.3    21.9    16.9   28  80.7
# 3   104.5 ...     31.0    26.2    37.0    34.8    23.0    16.6   23  72.6
# 4   107.5 ...     32.0    28.4    37.7    38.6    24.4    18.0   22  78.8
#
#      hgt  sex
# 0  174.0    1
# 1  175.3    1
# 2  193.5    1
# ...

# %%
#Splitting the dataframe based on gender
df_male = df[df['sex']==1]
df_female = df[df['sex']==0]

# %%
fm_height_mean = df_female['hgt'].mean()
fm_height_sd =  df_female['hgt'].std()

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.distplot(df_female['hgt'])
plt.show()

# %%
from scipy.stats import probplot
probplot(df_female['hgt'],plot=plt)
plt.show()

# %%
import statsmodels.api as sm
sm.qqplot(df_female['hgt'])
plt.show()

# %%
y=norm.pdf(df_female['hgt'].sort_values(),165,fm_height_sd)

plt.plot(df_female['hgt'].sort_values(),y,'-o')
plt.hist(df_female['hgt'],normed=1)
plt.show()

# %%
female = plt.scatter(df_female['hgt'],df_female['wgt'],color='blue')
male = plt.scatter(df_male['hgt'],df_male['wgt'],marker='x',color='red')
plt.legend((female,male),('Female',('Male')))
plt.title('ScatterPlot')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
pp_fm=sm.ProbPlot(df_female['hgt'].sample(200))
pp_m = sm.ProbPlot(df_male['hgt'].sample(200))
sm.qqplot_2samples(pp_fm,pp_m)
plt.show()

# %%
sns.distplot(df_male['hgt'])
plt.show()

# %%
sns.distplot(df_female['hgt'])
plt.show()
